# %%
import argparse
import pathlib
import numpy as np
import cv2
import time

import torch
import torch.nn as nn
from torch.autograd import Variable
from torchvision import transforms
import torch.backends.cudnn as cudnn
import torchvision

from PIL import Image
from PIL import Image, ImageOps

# from retinaface import RetinaFace
# from l2cs.detection.retinaface_detector import RetinaFace

from l2cs import select_device, draw_gaze, getArch, Pipeline, render


CWD = pathlib.Path.cwd()

# 设置参数
video_path = '../videos/video_1.mp4'  # 修改为你的视频路径
output_path = '../face_test.mp4'
device = 'gpu:0'  
arch = 'ResNet50'

cudnn.enabled = True

gaze_pipeline = Pipeline(
    weights=CWD / 'models' / 'L2CSNet_gaze360.pkl',
    arch='ResNet50',
    device = select_device(device, batch_size=256),
    confidence_threshold = 0.8
)
 
cap = cv2.VideoCapture(video_path)

# Check if the video file is opened correctly
if not cap.isOpened():
    raise IOError(f"Cannot open video file: {video_path}")

# Get video properties
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

# Define video writer
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

if not out.isOpened():
    raise IOError(f"Cannot create video writer for: {output_path}")

frame_count = 0

with torch.no_grad():
    while True:

        # Get frame
        success, frame = cap.read()    
        start_fps = time.time()  

        if not success:
            print("Video processing completed")
            break

        frame_count += 1
        print(f"Processing frame {frame_count}/{total_frames}")

        # Process frame
        results = gaze_pipeline.step(frame)

        # Visualize output
        frame = render(frame, results)
       
        myFPS = 1.0 / (time.time() - start_fps)
        cv2.putText(frame, 'FPS: {:.1f}'.format(myFPS), (10, 20),cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0, 255, 0), 1, cv2.LINE_AA)

        # Write frame to output video
        out.write(frame)

cap.release()
out.release()
print(f"Output video saved to: {output_path}")
# Out:
# Processing frame 1/68
# Processing frame 2/68
# Processing frame 3/68
# Processing frame 4/68
# Processing frame 5/68
# Processing frame 6/68
# Processing frame 7/68
# Processing frame 8/68
# Processing frame 9/68
# Processing frame 10/68
# Processing frame 11/68
# Processing frame 12/68
# Processing frame 13/68
# Processing frame 14/68
# Processing frame 15/68
# Processing frame 16/68
# Processing frame 17/68
# Processing frame 18/68
# Processing frame 19/68
# Processing frame 20/68
# Processing frame 21/68
# Processing frame 22/68
# Processing frame 23/68
# Processing frame 24/68
# Processing frame 25/68
# Processing frame 26/68
# Processing frame 27/68
# Processing frame 28/68
# Processing frame 29/68
# Processing frame 30/68
# Processing frame 31/68
# Processing frame 32/68
# Processing frame 33/68
# Processing frame 34/68
# Processing frame 35/68
# Processing frame 36/68
# Processing frame 37/68
# Processing frame 38/68
# Processing frame 39/68
# Processing frame 40/68
# Processing frame 41/68
# Processing frame 42/68
# Processing frame 43/68
# Processing frame 44/68
# Processing frame 45/68
# Processing frame 46/68
# Processing frame 47/68
# Processing frame 48/68
# Processing frame 49/68
# Processing frame 50/68
# Processing frame 51/68
# Processing frame 52/68
# Processing frame 53/68
# Processing frame 54/68
# Processing frame 55/68
# Processing frame 56/68
# Processing frame 57/68
# Processing frame 58/68
# Processing frame 59/68
# Processing frame 60/68
# Processing frame 61/68
# Processing frame 62/68
# Processing frame 63/68
# Processing frame 64/68
# Processing frame 65/68
# Processing frame 66/68
# Processing frame 67/68
# Processing frame 68/68
# Video processing completed
# Output video saved to: ../face_test.mp4

# %% [markdown]
# # obvious

# %%
import argparse
import pathlib
import numpy as np
import cv2
import time

import torch
import torch.nn as nn
from torch.autograd import Variable
from torchvision import transforms
import torch.backends.cudnn as cudnn
import torchvision

from PIL import Image
from PIL import Image, ImageOps

from face_detection import RetinaFace

from l2cs import select_device, Pipeline 
# 注意：我们不再使用 l2cs 的 render，而是自己写绘制逻辑

CWD = pathlib.Path.cwd()

# --- 自定义参数设置 ---
video_path = '../test_gaze/video_105.mp4'
output_path = '../output_gaze/video_105_obvious.mp4'
device = 'gpu:0' if torch.cuda.is_available() else 'cpu'
arch = 'ResNet50'

# *** 在这里修改箭头的样式 ***
ARROW_LENGTH = 300   # 箭头长度 (原版通常是 50-100，这里设为 200)
THICKNESS = 5        # 线条粗细 (原版通常是 2，这里设为 5)
COLOR = (0, 0, 255)  # 箭头颜色 (B, G, R)，这里是红色
TIP_LENGTH = 0.4     # 箭头尖端的比例 (0.0-1.0)，越大尖端越长

cudnn.enabled = True

gaze_pipeline = Pipeline(
    weights=CWD / 'models' / 'L2CSNet_gaze360.pkl',
    arch='ResNet50',
    device=select_device(device, batch_size=1)
)
 
cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    raise IOError(f"Cannot open video file: {video_path}")

fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

if not out.isOpened():
    raise IOError(f"Cannot create video writer for: {output_path}")

frame_count = 0

# --- 自定义绘制函数 ---
def render_custom(frame, results, length=100, thickness=2, color=(0, 0, 255)):

    pitch = results.pitch
    yaw = results.yaw
    bboxes = results.bboxes

    img = frame.copy()
    
    # 遍历每一张检测到的人脸
    for i in range(len(bboxes)):
        bbox = bboxes[i]
        
        # 计算人脸中心点 (起点)
        x_min, y_min, x_max, y_max = bbox
        cx = int((x_min + x_max) / 2)
        cy = int((y_min + y_max) / 2)
        
        # 绘制人脸框 (可选，如果你不需要框可以注释掉下面两行)
        cv2.rectangle(img, (int(x_min), int(y_min)), (int(x_max), int(y_max)), (0, 255, 0), 2)

        # 计算箭头终点
        # L2CS 的坐标系计算方式：
        # dx = -sin(yaw)
        # dy = sin(pitch)
        dx = -length * np.sin(yaw[i])
        dy = length * np.sin(pitch[i])
        
        tx = int(cx + dx)
        ty = int(cy + dy)
        
        # 绘制更粗更长的箭头
        cv2.arrowedLine(img, (cx, cy), (tx, ty), color, thickness, cv2.LINE_AA, tipLength=TIP_LENGTH)
        
        # 在中心点画个圆圈，让起点更明显 (可选)
        cv2.circle(img, (cx, cy), thickness * 2, (0, 255, 0), -1)

    return img

with torch.no_grad():
    while True:
        success, frame = cap.read()    
        start_fps = time.time()  

        if not success:
            print("Video processing completed")
            break

        frame_count += 1
        print(f"Processing frame {frame_count}/{total_frames}")

        # Process frame
        results = gaze_pipeline.step(frame)

        # Visualize output (使用自定义函数替代原来的 render)
        frame = render_custom(frame, results, length=ARROW_LENGTH, thickness=THICKNESS, color=COLOR)
       
        myFPS = 1.0 / (time.time() - start_fps)
        cv2.putText(frame, 'FPS: {:.1f}'.format(myFPS), (10, 20), cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0, 255, 0), 1, cv2.LINE_AA)

        out.write(frame)

cap.release()
out.release()
print(f"Output video saved to: {output_path}")

# %% [markdown]
# # process all

# %%
import argparse
import pathlib
import numpy as np
import cv2
import time
import os

import torch
import torch.nn as nn
from torch.autograd import Variable
from torchvision import transforms
import torch.backends.cudnn as cudnn
import torchvision

from PIL import Image
from PIL import Image, ImageOps

from l2cs import select_device, draw_gaze, getArch, Pipeline, render

# 1. 设置输入和输出文件夹路径
input_folder = pathlib.Path('../videos')
output_folder = pathlib.Path('../output_L2CS')

# 确保输出目录存在，如果不存在则创建
output_folder.mkdir(parents=True, exist_ok=True)

CWD = pathlib.Path.cwd()
device = 'gpu:0'  
arch = 'ResNet50'
cudnn.enabled = True

# 2. 加载模型 (放在循环外，只加载一次，节省时间)
print("Loading model...")
gaze_pipeline = Pipeline(
    weights=CWD / 'models' / 'L2CSNet_gaze360.pkl',
    arch='ResNet50',
    device=select_device(device, batch_size=512),
    confidence_threshold = 0.8
)
print("Model loaded.")

# 3. 获取所有视频文件 (这里以 .mp4 为例，需要其他格式可以加)
# pathlib.Path.glob 支持通配符
video_files = list(input_folder.glob('*.mp4')) 
# 如果还有 .avi 或 .mov，可以用: video_files.extend(input_folder.glob('*.avi'))

if not video_files:
    print(f"No video files found in {input_folder}")
    exit()

print(f"Found {len(video_files)} videos to process.")

# 4. 循环处理每个视频
for i, video_file in enumerate(video_files):
    video_path = str(video_file)
    # 保持原文件名，只改变路径
    output_path = str(output_folder / video_file.name)
    
    print(f"[{i+1}/{len(video_files)}] Start processing: {video_file.name}")
    
    cap = cv2.VideoCapture(video_path)

    if not cap.isOpened():
        print(f"Error: Cannot open video file: {video_path}, skipping...")
        continue

    # Get video properties
    fps = cap.get(cv2.CAP_PROP_FPS) # 有些视频FPS可能是浮点数
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    # Define video writer
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    if not out.isOpened():
        print(f"Error: Cannot create video writer for: {output_path}, skipping...")
        cap.release()
        continue

    frame_count = 0

    with torch.no_grad():
        while True:
            success, frame = cap.read()    
            start_fps = time.time()  

            if not success:
                break

            frame_count += 1
            # 每隔50帧打印一次进度，避免刷屏太快
            if frame_count % 50 == 0:
                print(f"  -> Processing frame {frame_count}/{total_frames}")

            # Process frame - 添加异常处理
            try:
                results = gaze_pipeline.step(frame)
            except ValueError as e:
                if 'need at least one array to stack' in str(e):
                    print(f"  Warning: No face detected in frame {frame_count}, skipping...")
                    out.write(frame)  # 写入原始帧
                    continue
                else:
                    raise

            # Visualize output
            frame = render(frame, results)
        
            # Calculate and draw FPS
            end_time = time.time()
            time_diff = end_time - start_fps
            if time_diff > 0:
                myFPS = 1.0 / time_diff
            else:
                myFPS = 0.0
                
            cv2.putText(frame, 'FPS: {:.1f}'.format(myFPS), (10, 20),
                        cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0, 255, 0), 1, cv2.LINE_AA)

            # Write frame to output video
            out.write(frame)

    cap.release()
    out.release()
    print(f"Finished {video_file.name}. Saved to: {output_path}\n")

print("All videos processed!")
# Out:
# Loading model...
# Model loaded.
# Found 433 videos to process.
# [1/433] Start processing: video_83.mp4
#   -> Processing frame 50/55
# Finished video_83.mp4. Saved to: ../output_L2CS/video_83.mp4
#
# [2/433] Start processing: video_139.mp4
# Finished video_139.mp4. Saved to: ../output_L2CS/video_139.mp4
#
# [3/433] Start processing: video_36.mp4
#   -> Processing frame 50/94
# Finished video_36.mp4. Saved to: ../output_L2CS/video_36.mp4
#
# [4/433] Start processing: video_260.mp4
# Finished video_260.mp4. Saved to: ../output_L2CS/video_260.mp4
#
# [5/433] Start processing: video_70.mp4
#   -> Processing frame 50/81
# Finished video_70.mp4. Saved to: ../output_L2CS/video_70.mp4
#
# [6/433] Start processing: video_177.mp4
# Finished video_177.mp4. Saved to: ../output_L2CS/video_177.mp4
#
# [7/433] Start processing: video_433.mp4
#   -> Processing frame 50/60
# Finished video_433.mp4. Saved to: ../output_L2CS/video_433.mp4
#
# [8/433] Start processing: video_295.mp4
#   -> Processing frame 50/72
# Finished video_295.mp4. Saved to: ../output_L2CS/video_295.mp4
#
# [9/433] Start processing: video_426.mp4
#   -> Processing frame 50/65
# Finished video_426.mp4. Saved to: ../output_L2CS/video_426.mp4
#
# [10/433] Start processing: video_327.mp4
#   -> Processing frame 50/51
# Finished video_327.mp4. Saved to: ../output_L2CS/video_327.mp4
#
# [11/433] Start processing: video_360.mp4
# Finished video_360.mp4. Saved to: ../output_L2CS/video_360.mp4
#
# [12/433] Start processing: video_172.mp4
#   -> Processing frame 50/100
#   -> Processing frame 100/100
# Finished video_172.mp4. Saved to: ../output_L2CS/video_172.mp4
#
# [13/433] Start processing: video_129.mp4
# Finished video_129.mp4. Saved to: ../output_L2CS/video_129.mp4
#
# [14/433] Start processing: video_184.mp4
#   -> Processing frame 50/80
# Finished video_184.mp4. Saved to: ../output_L2CS/video_184.mp4
#
# [15/433] Start processing: video_33.mp4
# Finished video_33.mp4. Saved to: ../output_L2CS/video_33.mp4
#
# [16/433] Start processing: video_333.mp4
#   -> Processing frame 50/64
# Finished video_333.mp4. Saved to: ../output_L2CS/video_333.mp4
#
# [17/433] Start processing: video_37.mp4
#   -> Processing frame 50/80
# Finished video_37.mp4. Saved to: ../output_L2CS/video_37.mp4
#
# [18/433] Start processing: video_348.mp4
# Finished video_348.mp4. Saved to: ../output_L2CS/video_348.mp4
#
# [19/433] Start processing: video_412.mp4
#   -> Processing frame 50/55
# Finished video_412.mp4. Saved to: ../output_L2CS/video_412.mp4
#
# [20/433] Start processing: video_62.mp4
#   -> Processing frame 50/83
# Finished video_62.mp4. Saved to: ../output_L2CS/video_62.mp4
#
# [21/433] Start processing: video_237.mp4
# Finished video_237.mp4. Saved to: ../output_L2CS/video_237.mp4
#
# [22/433] Start processing: video_168.mp4
#   -> Processing frame 50/65
# Finished video_168.mp4. Saved to: ../output_L2CS/video_168.mp4
#
# [23/433] Start processing: video_284.mp4
#   -> Processing frame 50/55
# Finished video_284.mp4. Saved to: ../output_L2CS/video_284.mp4
#
# [24/433] Start processing: video_353.mp4
#   -> Processing frame 50/95
# Finished video_353.mp4. Saved to: ../output_L2CS/video_353.mp4
#
# [25/433] Start processing: video_34.mp4
# Finished video_34.mp4. Saved to: ../output_L2CS/video_34.mp4
#
# [26/433] Start processing: video_112.mp4
#   -> Processing frame 50/52
# Finished video_112.mp4. Saved to: ../output_L2CS/video_112.mp4
#
# [27/433] Start processing: video_207.mp4
#   -> Processing frame 50/53
# Finished video_207.mp4. Saved to: ../output_L2CS/video_207.mp4
#
# [28/433] Start processing: video_343.mp4
#   -> Processing frame 50/66
# Finished video_343.mp4. Saved to: ../output_L2CS/video_343.mp4
#
# [29/433] Start processing: video_126.mp4
#   -> Processing frame 50/75
# Finished video_126.mp4. Saved to: ../output_L2CS/video_126.mp4
#
# [30/433] Start processing: video_106.mp4
#   -> Processing frame 50/52
# Finished video_106.mp4. Saved to: ../output_L2CS/video_106.mp4
#
# [31/433] Start processing: video_337.mp4
#   -> Processing frame 50/79
# Finished video_337.mp4. Saved to: ../output_L2CS/video_337.mp4
#
# [32/433] Start processing: video_109.mp4
#   -> Processing frame 50/50
# Finished video_109.mp4. Saved to: ../output_L2CS/video_109.mp4
#
# [33/433] Start processing: video_101.mp4
#   -> Processing frame 50/58
# Finished video_101.mp4. Saved to: ../output_L2CS/video_101.mp4
#
# [34/433] Start processing: video_93.mp4
#   -> Processing frame 50/68
# Finished video_93.mp4. Saved to: ../output_L2CS/video_93.mp4
#
# [35/433] Start processing: video_51.mp4
#   -> Processing frame 50/57
# Finished video_51.mp4. Saved to: ../output_L2CS/video_51.mp4
#
# [36/433] Start processing: video_225.mp4
#   -> Processing frame 50/68
# Finished video_225.mp4. Saved to: ../output_L2CS/video_225.mp4
#
# [37/433] Start processing: video_272.mp4
# Finished video_272.mp4. Saved to: ../output_L2CS/video_272.mp4
#
# [38/433] Start processing: video_199.mp4
# Finished video_199.mp4. Saved to: ../output_L2CS/video_199.mp4
#
# [39/433] Start processing: video_352.mp4
# Finished video_352.mp4. Saved to: ../output_L2CS/video_352.mp4
#
# [40/433] Start processing: video_414.mp4
#   -> Processing frame 50/80
# Finished video_414.mp4. Saved to: ../output_L2CS/video_414.mp4
#
# [41/433] Start processing: video_406.mp4
#   -> Processing frame 50/75
# Finished video_406.mp4. Saved to: ../output_L2CS/video_406.mp4
#
# [42/433] Start processing: video_238.mp4
#   -> Processing frame 50/65
# Finished video_238.mp4. Saved to: ../output_L2CS/video_238.mp4
#
# [43/433] Start processing: video_269.mp4
#   -> Processing frame 50/65
# Finished video_269.mp4. Saved to: ../output_L2CS/video_269.mp4
#
# [44/433] Start processing: video_122.mp4
# Finished video_122.mp4. Saved to: ../output_L2CS/video_122.mp4
#
# [45/433] Start processing: video_384.mp4
# Finished video_384.mp4. Saved to: ../output_L2CS/video_384.mp4
#
# [46/433] Start processing: video_95.mp4
#   -> Processing frame 50/79
# Finished video_95.mp4. Saved to: ../output_L2CS/video_95.mp4
#
# [47/433] Start processing: video_128.mp4
#   -> Processing frame 50/75
# Finished video_128.mp4. Saved to: ../output_L2CS/video_128.mp4
#
# [48/433] Start processing: video_355.mp4
# Finished video_355.mp4. Saved to: ../output_L2CS/video_355.mp4
#
# [49/433] Start processing: video_351.mp4
#   -> Processing frame 50/67
# Finished video_351.mp4. Saved to: ../output_L2CS/video_351.mp4
#
# [50/433] Start processing: video_30.mp4
#   -> Processing frame 50/60
# Finished video_30.mp4. Saved to: ../output_L2CS/video_30.mp4
#
# [51/433] Start processing: video_175.mp4
# Finished video_175.mp4. Saved to: ../output_L2CS/video_175.mp4
#
# [52/433] Start processing: video_145.mp4
# Finished video_145.mp4. Saved to: ../output_L2CS/video_145.mp4
#
# [53/433] Start processing: video_389.mp4
# Finished video_389.mp4. Saved to: ../output_L2CS/video_389.mp4
#
# [54/433] Start processing: video_342.mp4
# Finished video_342.mp4. Saved to: ../output_L2CS/video_342.mp4
#
# [55/433] Start processing: video_255.mp4
# Finished video_255.mp4. Saved to: ../output_L2CS/video_255.mp4
#
# [56/433] Start processing: video_305.mp4
#   -> Processing frame 50/52
# Finished video_305.mp4. Saved to: ../output_L2CS/video_305.mp4
#
# [57/433] Start processing: video_161.mp4
# Finished video_161.mp4. Saved to: ../output_L2CS/video_161.mp4
#
# [58/433] Start processing: video_370.mp4
#   -> Processing frame 50/78
# Finished video_370.mp4. Saved to: ../output_L2CS/video_370.mp4
#
# [59/433] Start processing: video_10.mp4
#   -> Processing frame 50/77
# Finished video_10.mp4. Saved to: ../output_L2CS/video_10.mp4
#
# [60/433] Start processing: video_7.mp4
#   -> Processing frame 50/76
# Finished video_7.mp4. Saved to: ../output_L2CS/video_7.mp4
#
# [61/433] Start processing: video_257.mp4
#   -> Processing frame 50/57
# Finished video_257.mp4. Saved to: ../output_L2CS/video_257.mp4
#
# [62/433] Start processing: video_399.mp4
#   -> Processing frame 50/54
# Finished video_399.mp4. Saved to: ../output_L2CS/video_399.mp4
#
# [63/433] Start processing: video_21.mp4
#   -> Processing frame 50/94
# Finished video_21.mp4. Saved to: ../output_L2CS/video_21.mp4
#
# [64/433] Start processing: video_256.mp4
# Finished video_256.mp4. Saved to: ../output_L2CS/video_256.mp4
#
# [65/433] Start processing: video_289.mp4
#   -> Processing frame 50/84
# Finished video_289.mp4. Saved to: ../output_L2CS/video_289.mp4
#
# [66/433] Start processing: video_371.mp4
# Finished video_371.mp4. Saved to: ../output_L2CS/video_371.mp4
#
# [67/433] Start processing: video_388.mp4
# Finished video_388.mp4. Saved to: ../output_L2CS/video_388.mp4
#
# [68/433] Start processing: video_372.mp4
#   -> Processing frame 50/64
# Finished video_372.mp4. Saved to: ../output_L2CS/video_372.mp4
#
# [69/433] Start processing: video_125.mp4
#   -> Processing frame 50/68
# Finished video_125.mp4. Saved to: ../output_L2CS/video_125.mp4
#
# [70/433] Start processing: video_217.mp4
#   -> Processing frame 50/69
# Finished video_217.mp4. Saved to: ../output_L2CS/video_217.mp4
#
# [71/433] Start processing: video_212.mp4
#   -> Processing frame 50/57
# Finished video_212.mp4. Saved to: ../output_L2CS/video_212.mp4
#
# [72/433] Start processing: video_29.mp4
# Finished video_29.mp4. Saved to: ../output_L2CS/video_29.mp4
#
# [73/433] Start processing: video_228.mp4
#   -> Processing frame 50/69
# Finished video_228.mp4. Saved to: ../output_L2CS/video_228.mp4
#
# [74/433] Start processing: video_19.mp4
#   -> Processing frame 50/58
# Finished video_19.mp4. Saved to: ../output_L2CS/video_19.mp4
#
# [75/433] Start processing: video_361.mp4
# Finished video_361.mp4. Saved to: ../output_L2CS/video_361.mp4
#
# [76/433] Start processing: video_75.mp4
# Finished video_75.mp4. Saved to: ../output_L2CS/video_75.mp4
#
# [77/433] Start processing: video_181.mp4
#   -> Processing frame 50/57
# Finished video_181.mp4. Saved to: ../output_L2CS/video_181.mp4
#
# [78/433] Start processing: video_323.mp4
#   -> Processing frame 50/79
# Finished video_323.mp4. Saved to: ../output_L2CS/video_323.mp4
#
# [79/433] Start processing: video_301.mp4
#   -> Processing frame 50/58
# Finished video_301.mp4. Saved to: ../output_L2CS/video_301.mp4
#
# [80/433] Start processing: video_64.mp4
# Finished video_64.mp4. Saved to: ../output_L2CS/video_64.mp4
#
# [81/433] Start processing: video_349.mp4
# Finished video_349.mp4. Saved to: ../output_L2CS/video_349.mp4
#
# [82/433] Start processing: video_321.mp4
# Finished video_321.mp4. Saved to: ../output_L2CS/video_321.mp4
#
# [83/433] Start processing: video_266.mp4
# Finished video_266.mp4. Saved to: ../output_L2CS/video_266.mp4
#
# [84/433] Start processing: video_54.mp4
#   -> Processing frame 50/77
# Finished video_54.mp4. Saved to: ../output_L2CS/video_54.mp4
#
# [85/433] Start processing: video_306.mp4
#   -> Processing frame 50/64
# Finished video_306.mp4. Saved to: ../output_L2CS/video_306.mp4
#
# [86/433] Start processing: video_192.mp4
#   -> Processing frame 50/57
# Finished video_192.mp4. Saved to: ../output_L2CS/video_192.mp4
#
# [87/433] Start processing: video_196.mp4
#   -> Processing frame 50/55
# Finished video_196.mp4. Saved to: ../output_L2CS/video_196.mp4
#
# [88/433] Start processing: video_286.mp4
#   -> Processing frame 50/65
# Finished video_286.mp4. Saved to: ../output_L2CS/video_286.mp4
#
# [89/433] Start processing: video_141.mp4
#   -> Processing frame 50/60
# Finished video_141.mp4. Saved to: ../output_L2CS/video_141.mp4
#
# [90/433] Start processing: video_82.mp4
#   -> Processing frame 50/75
# Finished video_82.mp4. Saved to: ../output_L2CS/video_82.mp4
#
# [91/433] Start processing: video_41.mp4
# Finished video_41.mp4. Saved to: ../output_L2CS/video_41.mp4
#
# [92/433] Start processing: video_271.mp4
#   -> Processing frame 50/77
# Finished video_271.mp4. Saved to: ../output_L2CS/video_271.mp4
#
# [93/433] Start processing: video_335.mp4
# Finished video_335.mp4. Saved to: ../output_L2CS/video_335.mp4
#
# [94/433] Start processing: video_153.mp4
# Finished video_153.mp4. Saved to: ../output_L2CS/video_153.mp4
#
# [95/433] Start processing: video_84.mp4
# Finished video_84.mp4. Saved to: ../output_L2CS/video_84.mp4
#
# [96/433] Start processing: video_227.mp4
# Finished video_227.mp4. Saved to: ../output_L2CS/video_227.mp4
#
# [97/433] Start processing: video_136.mp4
#   -> Processing frame 50/82
# Finished video_136.mp4. Saved to: ../output_L2CS/video_136.mp4
#
# [98/433] Start processing: video_94.mp4
# Finished video_94.mp4. Saved to: ../output_L2CS/video_94.mp4
#
# [99/433] Start processing: video_252.mp4
#   -> Processing frame 50/83
# Finished video_252.mp4. Saved to: ../output_L2CS/video_252.mp4
#
# [100/433] Start processing: video_236.mp4
#   -> Processing frame 50/55
# Finished video_236.mp4. Saved to: ../output_L2CS/video_236.mp4
#
# [101/433] Start processing: video_180.mp4
#   -> Processing frame 50/81
# Finished video_180.mp4. Saved to: ../output_L2CS/video_180.mp4
#
# [102/433] Start processing: video_80.mp4
#   -> Processing frame 50/91
# Finished video_80.mp4. Saved to: ../output_L2CS/video_80.mp4
#
# [103/433] Start processing: video_224.mp4
#   -> Processing frame 50/73
# Finished video_224.mp4. Saved to: ../output_L2CS/video_224.mp4
#
# [104/433] Start processing: video_264.mp4
#   -> Processing frame 50/79
# Finished video_264.mp4. Saved to: ../output_L2CS/video_264.mp4
#
# [105/433] Start processing: video_234.mp4
#   -> Processing frame 50/54
# Finished video_234.mp4. Saved to: ../output_L2CS/video_234.mp4
#
# [106/433] Start processing: video_66.mp4
#   -> Processing frame 50/77
# Finished video_66.mp4. Saved to: ../output_L2CS/video_66.mp4
#
# [107/433] Start processing: video_28.mp4
#   -> Processing frame 50/70
# Finished video_28.mp4. Saved to: ../output_L2CS/video_28.mp4
#
# [108/433] Start processing: video_167.mp4
#   -> Processing frame 50/97
# Finished video_167.mp4. Saved to: ../output_L2CS/video_167.mp4
#
# [109/433] Start processing: video_345.mp4
# Finished video_345.mp4. Saved to: ../output_L2CS/video_345.mp4
#
# [110/433] Start processing: video_359.mp4
#   -> Processing frame 50/95
# Finished video_359.mp4. Saved to: ../output_L2CS/video_359.mp4
#
# [111/433] Start processing: video_268.mp4
# Finished video_268.mp4. Saved to: ../output_L2CS/video_268.mp4
#
# [112/433] Start processing: video_131.mp4
#   -> Processing frame 50/60
# Finished video_131.mp4. Saved to: ../output_L2CS/video_131.mp4
#
# [113/433] Start processing: video_375.mp4
#   -> Processing frame 50/51
# Finished video_375.mp4. Saved to: ../output_L2CS/video_375.mp4
#
# [114/433] Start processing: video_68.mp4
# Finished video_68.mp4. Saved to: ../output_L2CS/video_68.mp4
#
# [115/433] Start processing: video_298.mp4
# Finished video_298.mp4. Saved to: ../output_L2CS/video_298.mp4
#
# [116/433] Start processing: video_325.mp4
#   -> Processing frame 50/65
# Finished video_325.mp4. Saved to: ../output_L2CS/video_325.mp4
#
# [117/433] Start processing: video_92.mp4
#   -> Processing frame 50/57
# Finished video_92.mp4. Saved to: ../output_L2CS/video_92.mp4
#
# [118/433] Start processing: video_381.mp4
# Finished video_381.mp4. Saved to: ../output_L2CS/video_381.mp4
#
# [119/433] Start processing: video_155.mp4
# Finished video_155.mp4. Saved to: ../output_L2CS/video_155.mp4
#
# [120/433] Start processing: video_329.mp4
#   -> Processing frame 50/87
# Finished video_329.mp4. Saved to: ../output_L2CS/video_329.mp4
#
# [121/433] Start processing: video_211.mp4
#   -> Processing frame 50/71
# Finished video_211.mp4. Saved to: ../output_L2CS/video_211.mp4
#
# [122/433] Start processing: video_218.mp4
#   -> Processing frame 50/51
# Finished video_218.mp4. Saved to: ../output_L2CS/video_218.mp4
#
# [123/433] Start processing: video_326.mp4
#   -> Processing frame 50/81
# Finished video_326.mp4. Saved to: ../output_L2CS/video_326.mp4
#
# [124/433] Start processing: video_409.mp4
# Finished video_409.mp4. Saved to: ../output_L2CS/video_409.mp4
#
# [125/433] Start processing: video_56.mp4
#   -> Processing frame 50/91
# Finished video_56.mp4. Saved to: ../output_L2CS/video_56.mp4
#
# [126/433] Start processing: video_341.mp4
#   -> Processing frame 50/58
# Finished video_341.mp4. Saved to: ../output_L2CS/video_341.mp4
#
# [127/433] Start processing: video_416.mp4
#   -> Processing frame 50/82
# Finished video_416.mp4. Saved to: ../output_L2CS/video_416.mp4
#
# [128/433] Start processing: video_190.mp4
#   -> Processing frame 50/77
# Finished video_190.mp4. Saved to: ../output_L2CS/video_190.mp4
#
# [129/433] Start processing: video_281.mp4
# Finished video_281.mp4. Saved to: ../output_L2CS/video_281.mp4
#
# [130/433] Start processing: video_328.mp4
#   -> Processing frame 50/67
# Finished video_328.mp4. Saved to: ../output_L2CS/video_328.mp4
#
# [131/433] Start processing: video_282.mp4
# Finished video_282.mp4. Saved to: ../output_L2CS/video_282.mp4
#
# [132/433] Start processing: video_277.mp4
# Finished video_277.mp4. Saved to: ../output_L2CS/video_277.mp4
#
# [133/433] Start processing: video_102.mp4
#   -> Processing frame 50/85
# Finished video_102.mp4. Saved to: ../output_L2CS/video_102.mp4
#
# [134/433] Start processing: video_239.mp4
#   -> Processing frame 50/68
# Finished video_239.mp4. Saved to: ../output_L2CS/video_239.mp4
#
# [135/433] Start processing: video_311.mp4
# Finished video_311.mp4. Saved to: ../output_L2CS/video_311.mp4
#
# [136/433] Start processing: video_222.mp4
#   -> Processing frame 50/56
# Finished video_222.mp4. Saved to: ../output_L2CS/video_222.mp4
#
# [137/433] Start processing: video_26.mp4
#   -> Processing frame 50/74
# Finished video_26.mp4. Saved to: ../output_L2CS/video_26.mp4
#
# [138/433] Start processing: video_110.mp4
#   -> Processing frame 50/57
# Finished video_110.mp4. Saved to: ../output_L2CS/video_110.mp4
#
# [139/433] Start processing: video_152.mp4
# Finished video_152.mp4. Saved to: ../output_L2CS/video_152.mp4
#
# [140/433] Start processing: video_166.mp4
# Finished video_166.mp4. Saved to: ../output_L2CS/video_166.mp4
#
# [141/433] Start processing: video_420.mp4
# Finished video_420.mp4. Saved to: ../output_L2CS/video_420.mp4
#
# [142/433] Start processing: video_23.mp4
# Finished video_23.mp4. Saved to: ../output_L2CS/video_23.mp4
#
# [143/433] Start processing: video_380.mp4
#   -> Processing frame 50/80
# Finished video_380.mp4. Saved to: ../output_L2CS/video_380.mp4
#
# [144/433] Start processing: video_276.mp4
# Finished video_276.mp4. Saved to: ../output_L2CS/video_276.mp4
#
# [145/433] Start processing: video_9.mp4
#   -> Processing frame 50/58
# Finished video_9.mp4. Saved to: ../output_L2CS/video_9.mp4
#
# [146/433] Start processing: video_243.mp4
#   -> Processing frame 50/57
# Finished video_243.mp4. Saved to: ../output_L2CS/video_243.mp4
#
# [147/433] Start processing: video_219.mp4
#   -> Processing frame 50/71
# Finished video_219.mp4. Saved to: ../output_L2CS/video_219.mp4
#
# [148/433] Start processing: video_32.mp4
# Finished video_32.mp4. Saved to: ../output_L2CS/video_32.mp4
#
# [149/433] Start processing: video_48.mp4
# Finished video_48.mp4. Saved to: ../output_L2CS/video_48.mp4
#
# [150/433] Start processing: video_278.mp4
#   -> Processing frame 50/65
# Finished video_278.mp4. Saved to: ../output_L2CS/video_278.mp4
#
# [151/433] Start processing: video_425.mp4
#   -> Processing frame 50/89
# Finished video_425.mp4. Saved to: ../output_L2CS/video_425.mp4
#
# [152/433] Start processing: video_176.mp4
# Finished video_176.mp4. Saved to: ../output_L2CS/video_176.mp4
#
# [153/433] Start processing: video_322.mp4
# Finished video_322.mp4. Saved to: ../output_L2CS/video_322.mp4
#
# [154/433] Start processing: video_263.mp4
#   -> Processing frame 50/50
# Finished video_263.mp4. Saved to: ../output_L2CS/video_263.mp4
#
# [155/433] Start processing: video_133.mp4
# Finished video_133.mp4. Saved to: ../output_L2CS/video_133.mp4
#
# [156/433] Start processing: video_86.mp4
#   -> Processing frame 50/77
# Finished video_86.mp4. Saved to: ../output_L2CS/video_86.mp4
#
# [157/433] Start processing: video_206.mp4
#   -> Processing frame 50/66
# Finished video_206.mp4. Saved to: ../output_L2CS/video_206.mp4
#
# [158/433] Start processing: video_394.mp4
#   -> Processing frame 50/88
# Finished video_394.mp4. Saved to: ../output_L2CS/video_394.mp4
#
# [159/433] Start processing: video_287.mp4
#   -> Processing frame 50/83
# Finished video_287.mp4. Saved to: ../output_L2CS/video_287.mp4
#
# [160/433] Start processing: video_186.mp4
#   -> Processing frame 50/55
# Finished video_186.mp4. Saved to: ../output_L2CS/video_186.mp4
#
# [161/433] Start processing: video_383.mp4
# Finished video_383.mp4. Saved to: ../output_L2CS/video_383.mp4
#
# [162/433] Start processing: video_241.mp4
#   -> Processing frame 50/71
# Finished video_241.mp4. Saved to: ../output_L2CS/video_241.mp4
#
# [163/433] Start processing: video_59.mp4
# Finished video_59.mp4. Saved to: ../output_L2CS/video_59.mp4
#
# [164/433] Start processing: video_187.mp4
# Finished video_187.mp4. Saved to: ../output_L2CS/video_187.mp4
#
# [165/433] Start processing: video_140.mp4
# Finished video_140.mp4. Saved to: ../output_L2CS/video_140.mp4
#
# [166/433] Start processing: video_232.mp4
# Finished video_232.mp4. Saved to: ../output_L2CS/video_232.mp4
#
# [167/433] Start processing: video_285.mp4
# Finished video_285.mp4. Saved to: ../output_L2CS/video_285.mp4
#
# [168/433] Start processing: video_158.mp4
# Finished video_158.mp4. Saved to: ../output_L2CS/video_158.mp4
#
# [169/433] Start processing: video_49.mp4
# Finished video_49.mp4. Saved to: ../output_L2CS/video_49.mp4
#
# [170/433] Start processing: video_165.mp4
# Finished video_165.mp4. Saved to: ../output_L2CS/video_165.mp4
#
# [171/433] Start processing: video_385.mp4
#   -> Processing frame 50/74
# Finished video_385.mp4. Saved to: ../output_L2CS/video_385.mp4
#
# [172/433] Start processing: video_393.mp4
#   -> Processing frame 50/95
# Finished video_393.mp4. Saved to: ../output_L2CS/video_393.mp4
#
# [173/433] Start processing: video_105.mp4
#   -> Processing frame 50/92
# Finished video_105.mp4. Saved to: ../output_L2CS/video_105.mp4
#
# [174/433] Start processing: video_376.mp4
#   -> Processing frame 50/69
# Finished video_376.mp4. Saved to: ../output_L2CS/video_376.mp4
#
# [175/433] Start processing: video_338.mp4
#   -> Processing frame 50/51
# Finished video_338.mp4. Saved to: ../output_L2CS/video_338.mp4
#
# [176/433] Start processing: video_418.mp4
# Finished video_418.mp4. Saved to: ../output_L2CS/video_418.mp4
#
# [177/433] Start processing: video_45.mp4
# Finished video_45.mp4. Saved to: ../output_L2CS/video_45.mp4
#
# [178/433] Start processing: video_291.mp4
# Finished video_291.mp4. Saved to: ../output_L2CS/video_291.mp4
#
# [179/433] Start processing: video_108.mp4
#   -> Processing frame 50/99
# Finished video_108.mp4. Saved to: ../output_L2CS/video_108.mp4
#
# [180/433] Start processing: video_114.mp4
#   -> Processing frame 50/95
# Finished video_114.mp4. Saved to: ../output_L2CS/video_114.mp4
#
# [181/433] Start processing: video_307.mp4
#   -> Processing frame 50/100
#   -> Processing frame 100/100
# Finished video_307.mp4. Saved to: ../output_L2CS/video_307.mp4
#
# [182/433] Start processing: video_123.mp4
# Finished video_123.mp4. Saved to: ../output_L2CS/video_123.mp4
#
# [183/433] Start processing: video_366.mp4
# Finished video_366.mp4. Saved to: ../output_L2CS/video_366.mp4
#
# [184/433] Start processing: video_120.mp4
#   -> Processing frame 50/75
# Finished video_120.mp4. Saved to: ../output_L2CS/video_120.mp4
#
# [185/433] Start processing: video_226.mp4
#   -> Processing frame 50/54
# Finished video_226.mp4. Saved to: ../output_L2CS/video_226.mp4
#
# [186/433] Start processing: video_303.mp4
# Finished video_303.mp4. Saved to: ../output_L2CS/video_303.mp4
#
# [187/433] Start processing: video_310.mp4
#   -> Processing frame 50/54
# Finished video_310.mp4. Saved to: ../output_L2CS/video_310.mp4
#
# [188/433] Start processing: video_17.mp4
#   -> Processing frame 50/64
# Finished video_17.mp4. Saved to: ../output_L2CS/video_17.mp4
#
# [189/433] Start processing: video_273.mp4
# Finished video_273.mp4. Saved to: ../output_L2CS/video_273.mp4
#
# [190/433] Start processing: video_16.mp4
# Finished video_16.mp4. Saved to: ../output_L2CS/video_16.mp4
#
# [191/433] Start processing: video_431.mp4
#   -> Processing frame 50/86
# Finished video_431.mp4. Saved to: ../output_L2CS/video_431.mp4
#
# [192/433] Start processing: video_221.mp4
# Finished video_221.mp4. Saved to: ../output_L2CS/video_221.mp4
#
# [193/433] Start processing: video_300.mp4
#   -> Processing frame 50/88
# Finished video_300.mp4. Saved to: ../output_L2CS/video_300.mp4
#
# [194/433] Start processing: video_248.mp4
#   -> Processing frame 50/76
# Finished video_248.mp4. Saved to: ../output_L2CS/video_248.mp4
#
# [195/433] Start processing: video_294.mp4
#   -> Processing frame 50/63
# Finished video_294.mp4. Saved to: ../output_L2CS/video_294.mp4
#
# [196/433] Start processing: video_233.mp4
#   -> Processing frame 50/80
# Finished video_233.mp4. Saved to: ../output_L2CS/video_233.mp4
#
# [197/433] Start processing: video_203.mp4
#   -> Processing frame 50/57
# Finished video_203.mp4. Saved to: ../output_L2CS/video_203.mp4
#
# [198/433] Start processing: video_63.mp4
#   -> Processing frame 50/63
# Finished video_63.mp4. Saved to: ../output_L2CS/video_63.mp4
#
# [199/433] Start processing: video_15.mp4
# Finished video_15.mp4. Saved to: ../output_L2CS/video_15.mp4
#
# [200/433] Start processing: video_395.mp4
#   -> Processing frame 50/60
# Finished video_395.mp4. Saved to: ../output_L2CS/video_395.mp4
#
# [201/433] Start processing: video_1.mp4
#   -> Processing frame 50/68
# Finished video_1.mp4. Saved to: ../output_L2CS/video_1.mp4
#
# [202/433] Start processing: video_292.mp4
# Finished video_292.mp4. Saved to: ../output_L2CS/video_292.mp4
#
# [203/433] Start processing: video_405.mp4
# Finished video_405.mp4. Saved to: ../output_L2CS/video_405.mp4
#
# [204/433] Start processing: video_330.mp4
#   -> Processing frame 50/67
# Finished video_330.mp4. Saved to: ../output_L2CS/video_330.mp4
#
# [205/433] Start processing: video_147.mp4
# Finished video_147.mp4. Saved to: ../output_L2CS/video_147.mp4
#
# [206/433] Start processing: video_428.mp4
#   -> Processing frame 50/96
# Finished video_428.mp4. Saved to: ../output_L2CS/video_428.mp4
#
# [207/433] Start processing: video_138.mp4
#   -> Processing frame 50/90
# Finished video_138.mp4. Saved to: ../output_L2CS/video_138.mp4
#
# [208/433] Start processing: video_171.mp4
# Finished video_171.mp4. Saved to: ../output_L2CS/video_171.mp4
#
# [209/433] Start processing: video_79.mp4
#   -> Processing frame 50/66
# Finished video_79.mp4. Saved to: ../output_L2CS/video_79.mp4
#
# [210/433] Start processing: video_127.mp4
# Finished video_127.mp4. Saved to: ../output_L2CS/video_127.mp4
#
# [211/433] Start processing: video_270.mp4
# Finished video_270.mp4. Saved to: ../output_L2CS/video_270.mp4
#
# [212/433] Start processing: video_38.mp4
#   -> Processing frame 50/66
# Finished video_38.mp4. Saved to: ../output_L2CS/video_38.mp4
#
# [213/433] Start processing: video_53.mp4
#   -> Processing frame 50/74
# Finished video_53.mp4. Saved to: ../output_L2CS/video_53.mp4
#
# [214/433] Start processing: video_267.mp4
# Finished video_267.mp4. Saved to: ../output_L2CS/video_267.mp4
#
# [215/433] Start processing: video_379.mp4
#   -> Processing frame 50/78
# Finished video_379.mp4. Saved to: ../output_L2CS/video_379.mp4
#
# [216/433] Start processing: video_402.mp4
#   -> Processing frame 50/60
# Finished video_402.mp4. Saved to: ../output_L2CS/video_402.mp4
#
# [217/433] Start processing: video_44.mp4
#   -> Processing frame 50/63
# Finished video_44.mp4. Saved to: ../output_L2CS/video_44.mp4
#
# [218/433] Start processing: video_55.mp4
# Finished video_55.mp4. Saved to: ../output_L2CS/video_55.mp4
#
# [219/433] Start processing: video_410.mp4
# Finished video_410.mp4. Saved to: ../output_L2CS/video_410.mp4
#
# [220/433] Start processing: video_314.mp4
#   -> Processing frame 50/83
# Finished video_314.mp4. Saved to: ../output_L2CS/video_314.mp4
#
# [221/433] Start processing: video_265.mp4
# Finished video_265.mp4. Saved to: ../output_L2CS/video_265.mp4
#
# [222/433] Start processing: video_344.mp4
# Finished video_344.mp4. Saved to: ../output_L2CS/video_344.mp4
#
# [223/433] Start processing: video_81.mp4
#   -> Processing frame 50/71
# Finished video_81.mp4. Saved to: ../output_L2CS/video_81.mp4
#
# [224/433] Start processing: video_209.mp4
# Finished video_209.mp4. Saved to: ../output_L2CS/video_209.mp4
#
# [225/433] Start processing: video_151.mp4
# Finished video_151.mp4. Saved to: ../output_L2CS/video_151.mp4
#
# [226/433] Start processing: video_320.mp4
#   -> Processing frame 50/58
# Finished video_320.mp4. Saved to: ../output_L2CS/video_320.mp4
#
# [227/433] Start processing: video_319.mp4
#   -> Processing frame 50/76
# Finished video_319.mp4. Saved to: ../output_L2CS/video_319.mp4
#
# [228/433] Start processing: video_401.mp4
#   -> Processing frame 50/80
# Finished video_401.mp4. Saved to: ../output_L2CS/video_401.mp4
#
# [229/433] Start processing: video_432.mp4
# Finished video_432.mp4. Saved to: ../output_L2CS/video_432.mp4
#
# [230/433] Start processing: video_6.mp4
#   -> Processing frame 50/74
# Finished video_6.mp4. Saved to: ../output_L2CS/video_6.mp4
#
# [231/433] Start processing: video_254.mp4
# Finished video_254.mp4. Saved to: ../output_L2CS/video_254.mp4
#
# [232/433] Start processing: video_202.mp4
#   -> Processing frame 50/61
# Finished video_202.mp4. Saved to: ../output_L2CS/video_202.mp4
#
# [233/433] Start processing: video_398.mp4
#   -> Processing frame 50/53
# Finished video_398.mp4. Saved to: ../output_L2CS/video_398.mp4
#
# [234/433] Start processing: video_116.mp4
#   -> Processing frame 50/51
# Finished video_116.mp4. Saved to: ../output_L2CS/video_116.mp4
#
# [235/433] Start processing: video_396.mp4
#   -> Processing frame 50/81
# Finished video_396.mp4. Saved to: ../output_L2CS/video_396.mp4
#
# [236/433] Start processing: video_52.mp4
#   -> Processing frame 50/77
# Finished video_52.mp4. Saved to: ../output_L2CS/video_52.mp4
#
# [237/433] Start processing: video_377.mp4
# Finished video_377.mp4. Saved to: ../output_L2CS/video_377.mp4
#
# [238/433] Start processing: video_247.mp4
#   -> Processing frame 50/83
# Finished video_247.mp4. Saved to: ../output_L2CS/video_247.mp4
#
# [239/433] Start processing: video_261.mp4
#   -> Processing frame 50/92
# Finished video_261.mp4. Saved to: ../output_L2CS/video_261.mp4
#
# [240/433] Start processing: video_67.mp4
#   -> Processing frame 50/87
# Finished video_67.mp4. Saved to: ../output_L2CS/video_67.mp4
#
# [241/433] Start processing: video_24.mp4
#   -> Processing frame 50/81
# Finished video_24.mp4. Saved to: ../output_L2CS/video_24.mp4
#
# [242/433] Start processing: video_200.mp4
#   -> Processing frame 50/73
# Finished video_200.mp4. Saved to: ../output_L2CS/video_200.mp4
#
# [243/433] Start processing: video_35.mp4
#   -> Processing frame 50/83
# Finished video_35.mp4. Saved to: ../output_L2CS/video_35.mp4
#
# [244/433] Start processing: video_65.mp4
# Finished video_65.mp4. Saved to: ../output_L2CS/video_65.mp4
#
# [245/433] Start processing: video_130.mp4
# Finished video_130.mp4. Saved to: ../output_L2CS/video_130.mp4
#
# [246/433] Start processing: video_408.mp4
# Finished video_408.mp4. Saved to: ../output_L2CS/video_408.mp4
#
# [247/433] Start processing: video_331.mp4
#   -> Processing frame 50/85
# Finished video_331.mp4. Saved to: ../output_L2CS/video_331.mp4
#
# [248/433] Start processing: video_74.mp4
#   -> Processing frame 50/68
# Finished video_74.mp4. Saved to: ../output_L2CS/video_74.mp4
#
# [249/433] Start processing: video_347.mp4
#   -> Processing frame 50/68
# Finished video_347.mp4. Saved to: ../output_L2CS/video_347.mp4
#
# [250/433] Start processing: video_365.mp4
# Finished video_365.mp4. Saved to: ../output_L2CS/video_365.mp4
#
# [251/433] Start processing: video_164.mp4
#   -> Processing frame 50/88
# Finished video_164.mp4. Saved to: ../output_L2CS/video_164.mp4
#
# [252/433] Start processing: video_12.mp4
# Finished video_12.mp4. Saved to: ../output_L2CS/video_12.mp4
#
# [253/433] Start processing: video_22.mp4
# Finished video_22.mp4. Saved to: ../output_L2CS/video_22.mp4
#
# [254/433] Start processing: video_188.mp4
#   -> Processing frame 50/95
# Finished video_188.mp4. Saved to: ../output_L2CS/video_188.mp4
#
# [255/433] Start processing: video_216.mp4
# Finished video_216.mp4. Saved to: ../output_L2CS/video_216.mp4
#
# [256/433] Start processing: video_208.mp4
#   -> Processing frame 50/61
# Finished video_208.mp4. Saved to: ../output_L2CS/video_208.mp4
#
# [257/433] Start processing: video_124.mp4
#   -> Processing frame 50/59
# Finished video_124.mp4. Saved to: ../output_L2CS/video_124.mp4
#
# [258/433] Start processing: video_57.mp4
#   -> Processing frame 50/55
# Finished video_57.mp4. Saved to: ../output_L2CS/video_57.mp4
#
# [259/433] Start processing: video_91.mp4
# Finished video_91.mp4. Saved to: ../output_L2CS/video_91.mp4
#
# [260/433] Start processing: video_111.mp4
# Finished video_111.mp4. Saved to: ../output_L2CS/video_111.mp4
#
# [261/433] Start processing: video_13.mp4
#   -> Processing frame 50/64
# Finished video_13.mp4. Saved to: ../output_L2CS/video_13.mp4
#
# [262/433] Start processing: video_246.mp4
#   -> Processing frame 50/74
# Finished video_246.mp4. Saved to: ../output_L2CS/video_246.mp4
#
# [263/433] Start processing: video_258.mp4
# Finished video_258.mp4. Saved to: ../output_L2CS/video_258.mp4
#
# [264/433] Start processing: video_78.mp4
#   -> Processing frame 50/73
# Finished video_78.mp4. Saved to: ../output_L2CS/video_78.mp4
#
# [265/433] Start processing: video_27.mp4
# Finished video_27.mp4. Saved to: ../output_L2CS/video_27.mp4
#
# [266/433] Start processing: video_89.mp4
# Finished video_89.mp4. Saved to: ../output_L2CS/video_89.mp4
#
# [267/433] Start processing: video_373.mp4
#   -> Processing frame 50/77
# Finished video_373.mp4. Saved to: ../output_L2CS/video_373.mp4
#
# [268/433] Start processing: video_362.mp4
#   -> Processing frame 50/69
# Finished video_362.mp4. Saved to: ../output_L2CS/video_362.mp4
#
# [269/433] Start processing: video_174.mp4
#   -> Processing frame 50/74
# Finished video_174.mp4. Saved to: ../output_L2CS/video_174.mp4
#
# [270/433] Start processing: video_69.mp4
#   -> Processing frame 50/67
# Finished video_69.mp4. Saved to: ../output_L2CS/video_69.mp4
#
# [271/433] Start processing: video_50.mp4
#   -> Processing frame 50/52
# Finished video_50.mp4. Saved to: ../output_L2CS/video_50.mp4
#
# [272/433] Start processing: video_387.mp4
# Finished video_387.mp4. Saved to: ../output_L2CS/video_387.mp4
#
# [273/433] Start processing: video_302.mp4
#   -> Processing frame 50/99
# Finished video_302.mp4. Saved to: ../output_L2CS/video_302.mp4
#
# [274/433] Start processing: video_280.mp4
#   -> Processing frame 50/95
# Finished video_280.mp4. Saved to: ../output_L2CS/video_280.mp4
#
# [275/433] Start processing: video_214.mp4
# Finished video_214.mp4. Saved to: ../output_L2CS/video_214.mp4
#
# [276/433] Start processing: video_47.mp4
#   -> Processing frame 50/65
# Finished video_47.mp4. Saved to: ../output_L2CS/video_47.mp4
#
# [277/433] Start processing: video_14.mp4
#   -> Processing frame 50/83
# Finished video_14.mp4. Saved to: ../output_L2CS/video_14.mp4
#
# [278/433] Start processing: video_391.mp4
#   -> Processing frame 50/97
# Finished video_391.mp4. Saved to: ../output_L2CS/video_391.mp4
#
# [279/433] Start processing: video_296.mp4
#   -> Processing frame 50/70
# Finished video_296.mp4. Saved to: ../output_L2CS/video_296.mp4
#
# [280/433] Start processing: video_415.mp4
# Finished video_415.mp4. Saved to: ../output_L2CS/video_415.mp4
#
# [281/433] Start processing: video_392.mp4
#   -> Processing frame 50/58
# Finished video_392.mp4. Saved to: ../output_L2CS/video_392.mp4
#
# [282/433] Start processing: video_244.mp4
# Finished video_244.mp4. Saved to: ../output_L2CS/video_244.mp4
#
# [283/433] Start processing: video_149.mp4
# Finished video_149.mp4. Saved to: ../output_L2CS/video_149.mp4
#
# [284/433] Start processing: video_223.mp4
# Finished video_223.mp4. Saved to: ../output_L2CS/video_223.mp4
#
# [285/433] Start processing: video_422.mp4
# Finished video_422.mp4. Saved to: ../output_L2CS/video_422.mp4
#
# [286/433] Start processing: video_72.mp4
#   -> Processing frame 50/86
# Finished video_72.mp4. Saved to: ../output_L2CS/video_72.mp4
#
# [287/433] Start processing: video_400.mp4
# Finished video_400.mp4. Saved to: ../output_L2CS/video_400.mp4
#
# [288/433] Start processing: video_358.mp4
# Finished video_358.mp4. Saved to: ../output_L2CS/video_358.mp4
#
# [289/433] Start processing: video_363.mp4
#   -> Processing frame 50/55
# Finished video_363.mp4. Saved to: ../output_L2CS/video_363.mp4
#
# [290/433] Start processing: video_397.mp4
#   -> Processing frame 50/50
# Finished video_397.mp4. Saved to: ../output_L2CS/video_397.mp4
#
# [291/433] Start processing: video_230.mp4
#   -> Processing frame 50/82
# Finished video_230.mp4. Saved to: ../output_L2CS/video_230.mp4
#
# [292/433] Start processing: video_427.mp4
# Finished video_427.mp4. Saved to: ../output_L2CS/video_427.mp4
#
# [293/433] Start processing: video_183.mp4
#   -> Processing frame 50/64
# Finished video_183.mp4. Saved to: ../output_L2CS/video_183.mp4
#
# [294/433] Start processing: video_251.mp4
#   -> Processing frame 50/82
# Finished video_251.mp4. Saved to: ../output_L2CS/video_251.mp4
#
# [295/433] Start processing: video_242.mp4
#   -> Processing frame 50/74
# Finished video_242.mp4. Saved to: ../output_L2CS/video_242.mp4
#
# [296/433] Start processing: video_18.mp4
#   -> Processing frame 50/68
# Finished video_18.mp4. Saved to: ../output_L2CS/video_18.mp4
#
# [297/433] Start processing: video_137.mp4
# Finished video_137.mp4. Saved to: ../output_L2CS/video_137.mp4
#
# [298/433] Start processing: video_312.mp4
# Finished video_312.mp4. Saved to: ../output_L2CS/video_312.mp4
#
# [299/433] Start processing: video_390.mp4
# Finished video_390.mp4. Saved to: ../output_L2CS/video_390.mp4
#
# [300/433] Start processing: video_316.mp4
# Finished video_316.mp4. Saved to: ../output_L2CS/video_316.mp4
#
# [301/433] Start processing: video_31.mp4
#   -> Processing frame 50/77
# Finished video_31.mp4. Saved to: ../output_L2CS/video_31.mp4
#
# [302/433] Start processing: video_71.mp4
#   -> Processing frame 50/53
# Finished video_71.mp4. Saved to: ../output_L2CS/video_71.mp4
#
# [303/433] Start processing: video_160.mp4
# Finished video_160.mp4. Saved to: ../output_L2CS/video_160.mp4
#
# [304/433] Start processing: video_336.mp4
#   -> Processing frame 50/81
# Finished video_336.mp4. Saved to: ../output_L2CS/video_336.mp4
#
# [305/433] Start processing: video_250.mp4
# Finished video_250.mp4. Saved to: ../output_L2CS/video_250.mp4
#
# [306/433] Start processing: video_178.mp4
#   -> Processing frame 50/52
# Finished video_178.mp4. Saved to: ../output_L2CS/video_178.mp4
#
# [307/433] Start processing: video_135.mp4
#   -> Processing frame 50/72
# Finished video_135.mp4. Saved to: ../output_L2CS/video_135.mp4
#
# [308/433] Start processing: video_170.mp4
#   -> Processing frame 50/66
# Finished video_170.mp4. Saved to: ../output_L2CS/video_170.mp4
#
# [309/433] Start processing: video_195.mp4
#   -> Processing frame 50/91
# Finished video_195.mp4. Saved to: ../output_L2CS/video_195.mp4
#
# [310/433] Start processing: video_103.mp4
#   -> Processing frame 50/60
# Finished video_103.mp4. Saved to: ../output_L2CS/video_103.mp4
#
# [311/433] Start processing: video_430.mp4
# Finished video_430.mp4. Saved to: ../output_L2CS/video_430.mp4
#
# [312/433] Start processing: video_115.mp4
# Finished video_115.mp4. Saved to: ../output_L2CS/video_115.mp4
#
# [313/433] Start processing: video_346.mp4
#   -> Processing frame 50/50
# Finished video_346.mp4. Saved to: ../output_L2CS/video_346.mp4
#
# [314/433] Start processing: video_407.mp4
#   -> Processing frame 50/82
# Finished video_407.mp4. Saved to: ../output_L2CS/video_407.mp4
#
# [315/433] Start processing: video_8.mp4
# Finished video_8.mp4. Saved to: ../output_L2CS/video_8.mp4
#
# [316/433] Start processing: video_201.mp4
# Finished video_201.mp4. Saved to: ../output_L2CS/video_201.mp4
#
# [317/433] Start processing: video_205.mp4
#   -> Processing frame 50/70
# Finished video_205.mp4. Saved to: ../output_L2CS/video_205.mp4
#
# [318/433] Start processing: video_424.mp4
#   -> Processing frame 50/71
# Finished video_424.mp4. Saved to: ../output_L2CS/video_424.mp4
#
# [319/433] Start processing: video_259.mp4
# Finished video_259.mp4. Saved to: ../output_L2CS/video_259.mp4
#
# [320/433] Start processing: video_423.mp4
#   -> Processing frame 50/88
# Finished video_423.mp4. Saved to: ../output_L2CS/video_423.mp4
#
# [321/433] Start processing: video_293.mp4
#   -> Processing frame 50/93
# Finished video_293.mp4. Saved to: ../output_L2CS/video_293.mp4
#
# [322/433] Start processing: video_253.mp4
#   -> Processing frame 50/76
# Finished video_253.mp4. Saved to: ../output_L2CS/video_253.mp4
#
# [323/433] Start processing: video_87.mp4
# Finished video_87.mp4. Saved to: ../output_L2CS/video_87.mp4
#
# [324/433] Start processing: video_283.mp4
# Finished video_283.mp4. Saved to: ../output_L2CS/video_283.mp4
#
# [325/433] Start processing: video_421.mp4
# Finished video_421.mp4. Saved to: ../output_L2CS/video_421.mp4
#
# [326/433] Start processing: video_42.mp4
# Finished video_42.mp4. Saved to: ../output_L2CS/video_42.mp4
#
# [327/433] Start processing: video_60.mp4
#   -> Processing frame 50/78
# Finished video_60.mp4. Saved to: ../output_L2CS/video_60.mp4
#
# [328/433] Start processing: video_132.mp4
#   -> Processing frame 50/66
# Finished video_132.mp4. Saved to: ../output_L2CS/video_132.mp4
#
# [329/433] Start processing: video_197.mp4
#   -> Processing frame 50/51
# Finished video_197.mp4. Saved to: ../output_L2CS/video_197.mp4
#
# [330/433] Start processing: video_419.mp4
#   -> Processing frame 50/65
# Finished video_419.mp4. Saved to: ../output_L2CS/video_419.mp4
#
# [331/433] Start processing: video_76.mp4
#   -> Processing frame 50/54
# Finished video_76.mp4. Saved to: ../output_L2CS/video_76.mp4
#
# [332/433] Start processing: video_279.mp4
#   -> Processing frame 50/89
# Finished video_279.mp4. Saved to: ../output_L2CS/video_279.mp4
#
# [333/433] Start processing: video_429.mp4
#   -> Processing frame 50/71
# Finished video_429.mp4. Saved to: ../output_L2CS/video_429.mp4
#
# [334/433] Start processing: video_144.mp4
#   -> Processing frame 50/79
# Finished video_144.mp4. Saved to: ../output_L2CS/video_144.mp4
#
# [335/433] Start processing: video_179.mp4
# Finished video_179.mp4. Saved to: ../output_L2CS/video_179.mp4
#
# [336/433] Start processing: video_148.mp4
#   -> Processing frame 50/55
# Finished video_148.mp4. Saved to: ../output_L2CS/video_148.mp4
#
# [337/433] Start processing: video_297.mp4
#   -> Processing frame 50/93
# Finished video_297.mp4. Saved to: ../output_L2CS/video_297.mp4
#
# [338/433] Start processing: video_113.mp4
#   -> Processing frame 50/75
# Finished video_113.mp4. Saved to: ../output_L2CS/video_113.mp4
#
# [339/433] Start processing: video_119.mp4
#   -> Processing frame 50/90
# Finished video_119.mp4. Saved to: ../output_L2CS/video_119.mp4
#
# [340/433] Start processing: video_332.mp4
#   -> Processing frame 50/59
# Finished video_332.mp4. Saved to: ../output_L2CS/video_332.mp4
#
# [341/433] Start processing: video_339.mp4
#   -> Processing frame 50/75
# Finished video_339.mp4. Saved to: ../output_L2CS/video_339.mp4
#
# [342/433] Start processing: video_73.mp4
# Finished video_73.mp4. Saved to: ../output_L2CS/video_73.mp4
#
# [343/433] Start processing: video_231.mp4
#   -> Processing frame 50/54
# Finished video_231.mp4. Saved to: ../output_L2CS/video_231.mp4
#
# [344/433] Start processing: video_3.mp4
#   -> Processing frame 50/81
# Finished video_3.mp4. Saved to: ../output_L2CS/video_3.mp4
#
# [345/433] Start processing: video_11.mp4
#   -> Processing frame 50/92
# Finished video_11.mp4. Saved to: ../output_L2CS/video_11.mp4
#
# [346/433] Start processing: video_334.mp4
#   -> Processing frame 50/72
# Finished video_334.mp4. Saved to: ../output_L2CS/video_334.mp4
#
# [347/433] Start processing: video_194.mp4
# Finished video_194.mp4. Saved to: ../output_L2CS/video_194.mp4
#
# [348/433] Start processing: video_413.mp4
# Finished video_413.mp4. Saved to: ../output_L2CS/video_413.mp4
#
# [349/433] Start processing: video_204.mp4
# Finished video_204.mp4. Saved to: ../output_L2CS/video_204.mp4
#
# [350/433] Start processing: video_162.mp4
#   -> Processing frame 50/71
# Finished video_162.mp4. Saved to: ../output_L2CS/video_162.mp4
#
# [351/433] Start processing: video_382.mp4
# Finished video_382.mp4. Saved to: ../output_L2CS/video_382.mp4
#
# [352/433] Start processing: video_189.mp4
#   -> Processing frame 50/66
# Finished video_189.mp4. Saved to: ../output_L2CS/video_189.mp4
#
# [353/433] Start processing: video_350.mp4
#   -> Processing frame 50/57
# Finished video_350.mp4. Saved to: ../output_L2CS/video_350.mp4
#
# [354/433] Start processing: video_308.mp4
#   -> Processing frame 50/94
# Finished video_308.mp4. Saved to: ../output_L2CS/video_308.mp4
#
# [355/433] Start processing: video_77.mp4
#   -> Processing frame 50/72
# Finished video_77.mp4. Saved to: ../output_L2CS/video_77.mp4
#
# [356/433] Start processing: video_96.mp4
#   -> Processing frame 50/60
# Finished video_96.mp4. Saved to: ../output_L2CS/video_96.mp4
#
# [357/433] Start processing: video_121.mp4
#   -> Processing frame 50/87
# Finished video_121.mp4. Saved to: ../output_L2CS/video_121.mp4
#
# [358/433] Start processing: video_43.mp4
# Finished video_43.mp4. Saved to: ../output_L2CS/video_43.mp4
#
# [359/433] Start processing: video_61.mp4
#   -> Processing frame 50/84
# Finished video_61.mp4. Saved to: ../output_L2CS/video_61.mp4
#
# [360/433] Start processing: video_245.mp4
#   -> Processing frame 50/92
# Finished video_245.mp4. Saved to: ../output_L2CS/video_245.mp4
#
# [361/433] Start processing: video_220.mp4
# Finished video_220.mp4. Saved to: ../output_L2CS/video_220.mp4
#
# [362/433] Start processing: video_156.mp4
# Finished video_156.mp4. Saved to: ../output_L2CS/video_156.mp4
#
# [363/433] Start processing: video_39.mp4
#   -> Processing frame 50/53
# Finished video_39.mp4. Saved to: ../output_L2CS/video_39.mp4
#
# [364/433] Start processing: video_340.mp4
# Finished video_340.mp4. Saved to: ../output_L2CS/video_340.mp4
#
# [365/433] Start processing: video_88.mp4
# Finished video_88.mp4. Saved to: ../output_L2CS/video_88.mp4
#
# [366/433] Start processing: video_354.mp4
# Finished video_354.mp4. Saved to: ../output_L2CS/video_354.mp4
#
# [367/433] Start processing: video_309.mp4
#   -> Processing frame 50/84
# Finished video_309.mp4. Saved to: ../output_L2CS/video_309.mp4
#
# [368/433] Start processing: video_386.mp4
#   -> Processing frame 50/94
# Finished video_386.mp4. Saved to: ../output_L2CS/video_386.mp4
#
# [369/433] Start processing: video_20.mp4
# Finished video_20.mp4. Saved to: ../output_L2CS/video_20.mp4
#
# [370/433] Start processing: video_315.mp4
#   -> Processing frame 50/58
# Finished video_315.mp4. Saved to: ../output_L2CS/video_315.mp4
#
# [371/433] Start processing: video_182.mp4
#   -> Processing frame 50/91
# Finished video_182.mp4. Saved to: ../output_L2CS/video_182.mp4
#
# [372/433] Start processing: video_275.mp4
#   -> Processing frame 50/60
# Finished video_275.mp4. Saved to: ../output_L2CS/video_275.mp4
#
# [373/433] Start processing: video_99.mp4
#   -> Processing frame 50/68
# Finished video_99.mp4. Saved to: ../output_L2CS/video_99.mp4
#
# [374/433] Start processing: video_191.mp4
# Finished video_191.mp4. Saved to: ../output_L2CS/video_191.mp4
#
# [375/433] Start processing: video_324.mp4
#   -> Processing frame 50/85
# Finished video_324.mp4. Saved to: ../output_L2CS/video_324.mp4
#
# [376/433] Start processing: video_46.mp4
# Finished video_46.mp4. Saved to: ../output_L2CS/video_46.mp4
#
# [377/433] Start processing: video_159.mp4
#   -> Processing frame 50/59
# Finished video_159.mp4. Saved to: ../output_L2CS/video_159.mp4
#
# [378/433] Start processing: video_404.mp4
#   -> Processing frame 50/73
# Finished video_404.mp4. Saved to: ../output_L2CS/video_404.mp4
#
# [379/433] Start processing: video_193.mp4
#   -> Processing frame 50/71
# Finished video_193.mp4. Saved to: ../output_L2CS/video_193.mp4
#
# [380/433] Start processing: video_313.mp4
# Finished video_313.mp4. Saved to: ../output_L2CS/video_313.mp4
#
# [381/433] Start processing: video_25.mp4
# Finished video_25.mp4. Saved to: ../output_L2CS/video_25.mp4
#
# [382/433] Start processing: video_4.mp4
# Finished video_4.mp4. Saved to: ../output_L2CS/video_4.mp4
#
# [383/433] Start processing: video_163.mp4
# Finished video_163.mp4. Saved to: ../output_L2CS/video_163.mp4
#
# [384/433] Start processing: video_378.mp4
# Finished video_378.mp4. Saved to: ../output_L2CS/video_378.mp4
#
# [385/433] Start processing: video_90.mp4
#   -> Processing frame 50/64
# Finished video_90.mp4. Saved to: ../output_L2CS/video_90.mp4
#
# [386/433] Start processing: video_235.mp4
#   -> Processing frame 50/94
# Finished video_235.mp4. Saved to: ../output_L2CS/video_235.mp4
#
# [387/433] Start processing: video_357.mp4
#   -> Processing frame 50/79
# Finished video_357.mp4. Saved to: ../output_L2CS/video_357.mp4
#
# [388/433] Start processing: video_150.mp4
#   -> Processing frame 50/56
# Finished video_150.mp4. Saved to: ../output_L2CS/video_150.mp4
#
# [389/433] Start processing: video_157.mp4
#   -> Processing frame 50/81
# Finished video_157.mp4. Saved to: ../output_L2CS/video_157.mp4
#
# [390/433] Start processing: video_249.mp4
# Finished video_249.mp4. Saved to: ../output_L2CS/video_249.mp4
#
# [391/433] Start processing: video_299.mp4
# Finished video_299.mp4. Saved to: ../output_L2CS/video_299.mp4
#
# [392/433] Start processing: video_317.mp4
# Finished video_317.mp4. Saved to: ../output_L2CS/video_317.mp4
#
# [393/433] Start processing: video_403.mp4
#   -> Processing frame 50/63
# Finished video_403.mp4. Saved to: ../output_L2CS/video_403.mp4
#
# [394/433] Start processing: video_356.mp4
#   -> Processing frame 50/59
# Finished video_356.mp4. Saved to: ../output_L2CS/video_356.mp4
#
# [395/433] Start processing: video_274.mp4
# Finished video_274.mp4. Saved to: ../output_L2CS/video_274.mp4
#
# [396/433] Start processing: video_262.mp4
# Finished video_262.mp4. Saved to: ../output_L2CS/video_262.mp4
#
# [397/433] Start processing: video_240.mp4
#   -> Processing frame 50/56
# Finished video_240.mp4. Saved to: ../output_L2CS/video_240.mp4
#
# [398/433] Start processing: video_107.mp4
#   -> Processing frame 50/86
# Finished video_107.mp4. Saved to: ../output_L2CS/video_107.mp4
#
# [399/433] Start processing: video_143.mp4
#   -> Processing frame 50/71
# Finished video_143.mp4. Saved to: ../output_L2CS/video_143.mp4
#
# [400/433] Start processing: video_369.mp4
#   -> Processing frame 50/51
# Finished video_369.mp4. Saved to: ../output_L2CS/video_369.mp4
#
# [401/433] Start processing: video_210.mp4
# Finished video_210.mp4. Saved to: ../output_L2CS/video_210.mp4
#
# [402/433] Start processing: video_417.mp4
#   -> Processing frame 50/71
# Finished video_417.mp4. Saved to: ../output_L2CS/video_417.mp4
#
# [403/433] Start processing: video_134.mp4
# Finished video_134.mp4. Saved to: ../output_L2CS/video_134.mp4
#
# [404/433] Start processing: video_364.mp4
#   -> Processing frame 50/67
# Finished video_364.mp4. Saved to: ../output_L2CS/video_364.mp4
#
# [405/433] Start processing: video_169.mp4
#   -> Processing frame 50/54
# Finished video_169.mp4. Saved to: ../output_L2CS/video_169.mp4
#
# [406/433] Start processing: video_290.mp4
# Finished video_290.mp4. Saved to: ../output_L2CS/video_290.mp4
#
# [407/433] Start processing: video_146.mp4
# Finished video_146.mp4. Saved to: ../output_L2CS/video_146.mp4
#
# [408/433] Start processing: video_2.mp4
#   -> Processing frame 50/60
# Finished video_2.mp4. Saved to: ../output_L2CS/video_2.mp4
#
# [409/433] Start processing: video_229.mp4
# Finished video_229.mp4. Saved to: ../output_L2CS/video_229.mp4
#
# [410/433] Start processing: video_368.mp4
# Finished video_368.mp4. Saved to: ../output_L2CS/video_368.mp4
#
# [411/433] Start processing: video_215.mp4
# Finished video_215.mp4. Saved to: ../output_L2CS/video_215.mp4
#
# [412/433] Start processing: video_367.mp4
#   -> Processing frame 50/83
# Finished video_367.mp4. Saved to: ../output_L2CS/video_367.mp4
#
# [413/433] Start processing: video_213.mp4
#   -> Processing frame 50/80
# Finished video_213.mp4. Saved to: ../output_L2CS/video_213.mp4
#
# [414/433] Start processing: video_374.mp4
#   -> Processing frame 50/82
# Finished video_374.mp4. Saved to: ../output_L2CS/video_374.mp4
#
# [415/433] Start processing: video_411.mp4
#   -> Processing frame 50/75
# Finished video_411.mp4. Saved to: ../output_L2CS/video_411.mp4
#
# [416/433] Start processing: video_98.mp4
#   -> Processing frame 50/76
# Finished video_98.mp4. Saved to: ../output_L2CS/video_98.mp4
#
# [417/433] Start processing: video_104.mp4
#   -> Processing frame 50/51
# Finished video_104.mp4. Saved to: ../output_L2CS/video_104.mp4
#
# [418/433] Start processing: video_173.mp4
#   -> Processing frame 50/81
# Finished video_173.mp4. Saved to: ../output_L2CS/video_173.mp4
#
# [419/433] Start processing: video_185.mp4
# Finished video_185.mp4. Saved to: ../output_L2CS/video_185.mp4
#
# [420/433] Start processing: video_318.mp4
#   -> Processing frame 50/87
# Finished video_318.mp4. Saved to: ../output_L2CS/video_318.mp4
#
# [421/433] Start processing: video_58.mp4
# Finished video_58.mp4. Saved to: ../output_L2CS/video_58.mp4
#
# [422/433] Start processing: video_40.mp4
#   -> Processing frame 50/94
# Finished video_40.mp4. Saved to: ../output_L2CS/video_40.mp4
#
# [423/433] Start processing: video_198.mp4
#   -> Processing frame 50/79
# Finished video_198.mp4. Saved to: ../output_L2CS/video_198.mp4
#
# [424/433] Start processing: video_97.mp4
# Finished video_97.mp4. Saved to: ../output_L2CS/video_97.mp4
#
# [425/433] Start processing: video_117.mp4
# Finished video_117.mp4. Saved to: ../output_L2CS/video_117.mp4
#
# [426/433] Start processing: video_118.mp4
#   -> Processing frame 50/57
# Finished video_118.mp4. Saved to: ../output_L2CS/video_118.mp4
#
# [427/433] Start processing: video_304.mp4
#   -> Processing frame 50/60
# Finished video_304.mp4. Saved to: ../output_L2CS/video_304.mp4
#
# [428/433] Start processing: video_5.mp4
#   -> Processing frame 50/54
# Finished video_5.mp4. Saved to: ../output_L2CS/video_5.mp4
#
# [429/433] Start processing: video_288.mp4
# Finished video_288.mp4. Saved to: ../output_L2CS/video_288.mp4
#
# [430/433] Start processing: video_100.mp4
#   -> Processing frame 50/81
# Finished video_100.mp4. Saved to: ../output_L2CS/video_100.mp4
#
# [431/433] Start processing: video_142.mp4
# Finished video_142.mp4. Saved to: ../output_L2CS/video_142.mp4
#
# [432/433] Start processing: video_154.mp4
#   -> Processing frame 50/79
# Finished video_154.mp4. Saved to: ../output_L2CS/video_154.mp4
#
# [433/433] Start processing: video_85.mp4
# Finished video_85.mp4. Saved to: ../output_L2CS/video_85.mp4
#
# All videos processed!
